# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 1
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
print("Por qué esta magnífica tecnología científica,\n"
	"\tque ahorra trabajo y nos hace la vida mas fácil,\n"
	"\t\tnos aporta tan poca felicidad?\n"
	"\t\t\tLa repuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.\n"
	"\n"
	'"Albert Einstein"')
# Out:
# Por qué esta magnífica tecnología científica,
# 	que ahorra trabajo y nos hace la vida mas fácil,
# 		nos aporta tan poca felicidad?
# 			La repuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.
#
# "Albert Einstein"

# %% [markdown]
# ## Ejercicio 2
# 1. Escribe el nombre de la calle de tu domicilio
# 2. Escribe el numero de la calle en otra
# 3. Población en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Crea una quinta variable que concatene todas ellas
# 6. Imprimela por pantalla

# %%
calle = "Can Sabat"
numero = 25
poblacion = "Barcelona"
codigo_postal = "08790"

direccion = calle + " " + str(numero) + ", " + poblacion + " " + codigo_postal
print(direccion)
# Out:
# Can Sabat 25, Barcelona 08790

# %% [markdown]
# ## Ejercicio 3
# Replica el output del ejercicio dos, pero está vez sin usar una variable intermedia que concatene todas las demas. Realiza este ejercicio en una línea, con un  único `print`

# %%
calle = "Can Sabat"
numero = 25
poblacion = "Barcelona"
codigo_postal = "08790"

# este método lo lei por interner que se puede desde la verisón 3.6 de python, para mi es mas facil de leer
print(f"calle : {calle} numero: {numero} poblacion: {poblacion} codigo postal: {codigo_postal}")
# Out:
# calle : Can Sabat numero: 25 poblacion: Barcelona codigo postal: 08790

# %% [markdown]
# ## Ejercicio 4
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. exec = True
# 6. import = 40
# 7. 81mi_variable = "Agua"
# 8. mi_variable10 = 6

# %% [markdown]
# 1. mi_varaible = "Economía"
# 2. otra_var = "Ejercicio"
# 3. true = "Ejercicio"
# 4. mi_variab1e = "Alpha"
# 5. exec = True
# 6. import1 = 40
# 7. mi_variable81 = "Agua"
# 8. i_variable10 = 6

# %%
mi_varaible = "Economía"
otra_var = "Ejercicio"
true = "Ejercicio"
mi_variab1e = "Alpha"
executar = True
import1 = 40
mi_variable81 = "Agua"
i_variable10 = 6

print(mi_varaible)
print(otra_var)
print(true)
print(mi_variab1e)
print(executar)
print(import1)
print(mi_variable81)
print(i_variable10)
# Out:
# Economía
# Ejercicio
# Ejercicio
# Alpha
# True
# 40
# Agua
# 6

# %% [markdown]
# ## Ejercicio 5
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = (C × 9 / 5) + 32

# %%
grados_f = input("Ingrese los grados a convertir: ")
grados_c = (float(grados_f) * 9/5) + 32 # no me daba el resultado correcto asi que la he cambiada
print(grados_c)
# Out:
# 30.555555555555557

# %% [markdown]
# ## Ejercicio 6
# Comenta en la medida de lo posible el Ejercicio 5. Será suficiente con poner al menos un comentario de línea, y otro multilínea

# %%
# manda un input para que el usuario devuelva la unidad que quiere convertir
grados_f = input("Ingrese los grados a convertir: ")
# convierte de fahrenheit a celsius
grados_c = (float(grados_f) * 9/5) + 32 # no me daba el resultado correcto asi que la he cambiada
# devuelve el resultado
print(grados_c)
# Out:
# 37.22222222222222
