# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics II

# %% [markdown]
# ## Ejercicio 1
# * Crea dos variables numericas: un `int` y un `float`
# * Comprueba sus tipos
# * Sumalas en otra nueva
# * ¿De qué tipo es la nueva variable?
# * Elimina las dos primeras variables creadas

# %%
variable1 = 3
variable2 = 4.5
print(type(variable1))
print(type(variable2))

variable3 = variable1 + variable2
print(type(variable3))
print(variable3)

del variable1, variable2
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# radianes = grados*(pi/180)

# %%
grados = input("Ingrese los grados a convertir: ")
grados = float(grados)
radianes = grados * (3.14 / 180)

print(f"Los radianes de {grados} es {radianes}")
# Out:
# Los radianes de 33.0 es 0.5756666666666668

# %% [markdown]
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
base = float(input("dime la base"))
altura = float(input("dime la altura)"))

area = base * altura
print(f"El area es {area}")
# Out:
# El area es 299.0

# %% [markdown]
# ## Ejercicio 4
# Tenemos las siguientes variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %%
a = 4
b = "Text"
c = 4.1

print(f"Si A y B son equivalentes : {a == b}")
print(f"Si A y C NO son equivalentes : {(a != b)}")
print(f"Si A es mayor que C : {(a > c)}")
print(f"Si C es menor o igual que A : {(c <= a)}")
print(f"Si B NO es equivalente a C : {(b != c)}")
# Out:
# Si A y B son equivalentes : False
# Si A y C NO son equivalentes : True
# Si A es mayor que C : False
# Si C es menor o igual que A : False
# Si B NO es equivalente a C : True

# %% [markdown]
# ## Ejercicio 5
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
pregunta1 = input("Dime un número: ")
pregunta2 = input("Dime otro número: ")

respuesta = pregunta1 == pregunta2
print(respuesta)
# Out:
# False

# %% [markdown]
# ## Ejercicio 6
# Mismo programa que en 5, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
pregunta1 = input("Dime un número: ")
pregunta2 = input("Dime otro número: ")
pregunta3 = input("Dime otro número: ")

print(f"Todas son iguales {pregunta1 == pregunta2 == pregunta3}")
print(f"Al menos 2 son iguales {pregunta1 == pregunta2 or pregunta1 == pregunta3 or pregunta2 == pregunta3}")
# Out:
# Todas son iguales False
# Al menos 2 son iguales True

# %% [markdown]
# ## Ejercicio 7
# Crea un programa que recoja dos inputs. Tiene que comprobar si su suma es igual, superior o inferior a 10

# %%
valor1 = input("input 1")
valor2 = input("input 2")

print(f"Es mayor que 10: {valor1 + valor2 > 10}")
print(f"Es menor que 10: {valor1 + valor2 < 10}")
print(f"Es igual que 10: {valor1 + valor2 == 10}")
# Out:
# Es mayor que 10: False
# Es menor que 10: False
# Es igual que 10: True

# %% [markdown]
# ## Ejercicio 8
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True

# %% [markdown]
# 1 - Falso
# 2 - Falso
# 3 - Falso
# 4 - Falso

# %% [markdown]
# ## Ejercicio 9
# Para este ejercicio vamos a poner en práctica [las funciones built in](https://docs.python.org/3/library/functions.html).
#
# 1. Calcula el máximo de la lista: [4, 6, 8, -1]
# 2. Suma todos los elementos de la lista anterior
# 3. Redondea este float a 3 dígitos decimales: 63.451256965
# 4. Valor absoluto de: -74

# %%
lista = [4,6,8,-1]

maximo = max(lista)
print(f"El máximo es {maximo}")

suma = sum(lista)
print(f"la suma es {suma}")

redondeo = round(sum(lista, 3))
print(f"la suma es {redondeo}")

absoluto = abs(-74)
print(f"el absoluto es {absoluto}")
# Out:
# El máximo es 8
# la suma es 17
# la suma es 20
# el absoluto es 74

# %% [markdown]
# ## Ejercicio 10
# Para el siguiente string se pide imprimir por pantalla los siguientes casos
#
#     "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."
#
# 1. Pásalo todo a mayúsculas
# 2. Pásalo todo a minúsculas
# 3. Solo la primera letra de cada palabra en mayúscula, el resto en minúscula
# 4. Crea una lista dividiéndolo por sus espacios
# 5. Sustituye las comas `,` por puntos y comas `;`
# 6. Elimina las `a` minúsculas

# %%
texto = "En un lugar de la Mancha, de cuyo nombre no quiero acordarme"
#uso print porque vscode solo me lanza la última variable.
print(f"texto todo en mayusculas : {texto.upper()}")
print(f"texto todo en minusculas : {texto.lower()}")
print(f"la primera siempre en mayusculas : {texto.title()}")
print(f"separamos todas las palabras : {texto.split(" ")}")
print(f"reemplazar , por ; : {texto.replace(",", ";")}")
print(f"eliminamos todas la a : {texto.replace("a", " ")}")
# Out:
# texto todo en mayusculas : EN UN LUGAR DE LA MANCHA, DE CUYO NOMBRE NO QUIERO ACORDARME
# texto todo en minusculas : en un lugar de la mancha, de cuyo nombre no quiero acordarme
# la primera siempre en mayusculas : En Un Lugar De La Mancha, De Cuyo Nombre No Quiero Acordarme
# separamos todas las palabras : ['En', 'un', 'lugar', 'de', 'la', 'Mancha,', 'de', 'cuyo', 'nombre', 'no', 'quiero', 'acordarme']
# reemplazar , por ; : En un lugar de la Mancha; de cuyo nombre no quiero acordarme
# eliminamos todas la a : En un lug r de l  M nch , de cuyo nombre no quiero  cord rme

# %% [markdown]
# ## Ejercicio 11
# 1. Crea una lista con 3 elementos numéricos
# 2. Añade un cuarto elemento
# 3. Calcula la suma de todos
# 4. Elimina el segundo elemento de la lista
# 5. Añade otro elemento en la posicion 3 de la lista
# 6. Crea otra lista con 4 elementos y concaténala a la que ya tenías.

# %%
lista = [1,5,7]

#Añadimos un valor a la lista
lista.append(9)

#Sumamos la lista
sum(lista)
#Mostramos la lista
print(lista)
#Eliminamos el valor 2 de la lista
lista.remove(1)
#Insertamos
lista.insert(1,2)
#Creamos una lista nueva
lista2 = [7,4,9]
#Concatenamos las 2 listas
resultado = lista + lista2
#Mostramos el resultado
print(resultado)
# Out:
# [1, 5, 7, 9]
# [5, 2, 7, 9, 7, 4, 9]
