# %%
import requests

root_path = "http://127.0.0.1:5000"

path = "/api/v3/resources/books/all"

#content = {'id': 2}

response = requests.get(url = root_path + path)
print(response)
print(response.text)
# Out:
# <Response [200]>
# {
#   "books": [
#     [
#       null,
#       2014,
#       "Ann Leckie ",
#       "Ancillary Justice",
#       "The body lay naked and facedown, a deathly gray, spatters of blood staining the snow around it."
#     ],
#     [
#       null,
#       2013,
#       "John Scalzi",
#       "Redshirts",
#       "From the top of the large boulder he sat on, Ensign Tom Davis looked across the expanse of the cave, toward Captain Lucius Abernathy, Science Officer Q\u2019eeng and Chief Engineer Paul West perched on a second, larger boulder, and thought, Well, this sucks."
#     ],
#     [
#       null,
#       2012,
#       "Jo Walton",
#       "Among Others",
#       "The Phurnacite factory in Abercwmboi killed all the trees for two miles around."
#     ],
#     [
#       null,
#       2011,
#       "Connie Willis",
#       "Blackout, All Clear (Vol. 2 - Blackout)",
# ...

# %%
root_path = "http://127.0.0.1:5000"

path = "/api/v1/resources/book/Jo Walton"

respuesta = requests.get(url=root_path+path)
print(respuesta)
print(respuesta.text)
# Out:
# <Response [200]>
# {
#   "books": [
#     [
#       null,
#       2012,
#       "Jo Walton",
#       "Among Others",
#       "The Phurnacite factory in Abercwmboi killed all the trees for two miles around."
#     ]
#   ]
# }

# %%
import requests
root_path = "http://127.0.0.1:5000"

path = "/api/v1/resources/book/filter"

contenido = {#"author": "Elsa",
             #"first_sentence": "En un lugar",
             #"id": 4,
             "published": "2014",
             #"title": "DS24"
             }
respuesta = requests.get(url=root_path+path, json = contenido)
print(respuesta)
print(respuesta.text)
# Out:
# <Response [200]>
# {
#   "books": [
#     [
#       null,
#       2014,
#       "Ann Leckie ",
#       "Ancillary Justice",
#       "The body lay naked and facedown, a deathly gray, spatters of blood staining the snow around it."
#     ]
#   ]
# }
